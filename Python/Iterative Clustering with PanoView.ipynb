# %%
from PanoramicView import scPanoView

# %%
LD = scPanoView.PanoView( filename = 'LD1', annotation = 'annotation')

# %%
LD.raw_exp.iloc[:3,:3]
vars(LD)
# Out:
# {'cell_anno': array([['Control_P5'],
#         ['Control_P5'],
#         ['Control_P5'],
#         ...,
#         ['Deprived_P7'],
#         ['Deprived_P7'],
#         ['Deprived_P7']], dtype=object),
#  'raw_exp':                AAACCCAAGCAACAAT-LD5RC  AAACCCAGTGCCTTTC-LD5RC  \
#  Xkr4                                0                       0
#  Gm37323                             0                       0
#  St18                                0                       0
#  Rrs1                                1                       0
#  3110035E14Rik                       0                       0
#  Mybl1                               0                       0
#  Cspp1                               2                       1
#  A830018L16Rik                       0                       0
#  Gm17644                             0                       0
#  Sulf1                               0                       0
#  Kcnb2                               0                       0
# ...

# %%
LD.RunSearching(GeneLow = 0.01, Zscore = 1.3, Normal=True, Log2=True)
# Out:
# Percentage of cells being analyzed: 21%
# Percentage of cells being analyzed: 25%
# Percentage of cells being analyzed: 30%
# Percentage of cells being analyzed: 70%
# Percentage of cells being analyzed: 75%
# Percentage of cells being analyzed: 94%
# Percentage of cells being analyzed: 94%
# Percentage of cells being analyzed: 95%
# Percentage of cells being analyzed: 96%
# Percentage of cells being analyzed: 96%
# Percentage of cells being analyzed: 97%
# Percentage of cells being analyzed: 99%
# Percentage of cells being analyzed: 99%
# Percentage of cells being analyzed: 99%
# Percentage of cells being analyzed: 99%
# Clusters generated

# %%
LD.OutputResult()
# Out:
# Output Cell_Membership.csv
# Output PanoView_output.png

# %%
LD.VisCluster(clevel=1,cnumber=4)

# %%
LD.VisClusterAnno()

# %%
LD.VisGeneExp(genes=['Aldh1l1','Cx3cr1','Mbp','Pdgfra'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Aldh1l1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-c49100d1ab08> in <module>
# ...

# %%
LD.RunVGs(clevel=1)

# %%
LD.HeatMapVGs(pval=0.05,number=50,fd=2,clevel=1)
